# %%
# !pip install pandas
import pandas as pd
SECONDS_IN_A_DAY = 3600 * 24
df = pd.read_csv("project-8400-GitHub-20240509T181710.csv")


df["created_at"] = pd.to_datetime(df["created_at"])
df["closed_at"] = pd.to_datetime(df["closed_at"])

df["delta_days"] = (
    (df["closed_at"] - df["created_at"]).dt.total_seconds() / SECONDS_IN_A_DAY
)

print("Delta days: ")
print(df["delta_days"].describe())

print("Delta days per repository: ")
print(df.groupby(["repository"])["delta_days"].describe())

print("Delta days per author: ")
print(df.groupby(["author_uuid"])["delta_days"].describe())
# Out:
# Collecting pandas
#   Using cached pandas-2.2.2-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (19 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2024.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 58.9 kB/s eta 0:00:0000:0100:08m
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 369.2 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 tzdata-2024.1
#                                          repository          id  pull_request  \
# 0                https://github.com/containers/crun   645561918          True
# 1                https://github.com/containers/crun   649791762         False
# 2                https://github.com/containers/crun   649793755          True
# 3                https://github.com/containers/crun   636291554         False
# 4                https://github.com/containers/crun   645492490          True
# ...                                             ...         ...           ...
# 48415  https://github.com/containers/podman-desktop  2279884914         False
# 48416  https://github.com/containers/podman-desktop  2286463209          True
# 48417  https://github.com/containers/podman-desktop  2265647979         False
# 48418  https://github.com/containers/podman-desktop  2287223201          True
# 48419  https://github.com/containers/podman-desktop  2136869865          True
#
#                                                      url  \
# 0            https://github.com/containers/crun/pull/419
# 1          https://github.com/containers/crun/issues/422
# 2            https://github.com/containers/crun/pull/423
# 3          https://github.com/containers/crun/issues/398
# 4            https://github.com/containers/crun/pull/416
# ...                                                  ...
# 48415  https://github.com/containers/podman-desktop/i...
# 48416  https://github.com/containers/podman-desktop/p...
# 48417  https://github.com/containers/podman-desktop/i...
# 48418  https://github.com/containers/podman-desktop/p...
# 48419  https://github.com/containers/podman-desktop/p...
#
#                  created_at             closed_at   state  \
# 0      2020-06-25T13:26:44Z  2020-07-01T20:45:52Z  closed
# 1      2020-03-12T13:36:06Z  2020-07-02T12:15:10Z  closed
# 2      2020-07-02T09:46:17Z  2020-07-02T12:15:10Z  closed
# 3      2020-06-10T14:24:34Z  2020-07-02T18:19:47Z  closed
# 4      2020-06-25T11:40:24Z  2020-07-02T18:19:47Z  closed
# ...                     ...                   ...     ...
# 48415  2024-05-06T02:06:41Z                   NaN    open
# 48416  2024-05-08T21:01:39Z                   NaN    open
# 48417  2024-04-26T12:07:40Z  2024-05-09T15:00:04Z  closed
# 48418  2024-05-09T08:56:17Z  2024-05-09T15:00:03Z  closed
# 48419  2024-02-15T15:48:22Z                   NaN    open
#
#                                     author_uuid  \
# 0      34ca73eea432e98955b2fd472788f958589dac04
# 1      36462949f2f3993570d6326e6542f482443542c8
# 2      34ca73eea432e98955b2fd472788f958589dac04
# 3      81b57a88bac7b4c339962b1d5e5b64eed20b1723
# 4      34ca73eea432e98955b2fd472788f958589dac04
# ...                                         ...
# 48415  bae7640a262da272da52a98f0584b270fe2a6d8c
# 48416  63cf1c8f81182ac85e1e6247bc8fdcec49f3cbc0
# 48417  3e67d03144461f2a915ac88bff342e1a8f01f808
# 48418  ab8f5080e00d2354cda7f7bc65141109638b4705
# 48419  63cf1c8f81182ac85e1e6247bc8fdcec49f3cbc0
#
#                              assignee_data_uuid
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 48415                                       NaN
# 48416                                       NaN
# 48417  ab8f5080e00d2354cda7f7bc65141109638b4705
# 48418                                       NaN
# 48419                                       NaN
#
# [48420 rows x 9 columns]
# Delta days:
# count    46487.000000
# mean        23.872133
# std         88.098863
# min          0.000046
# 25%          0.166852
# 50%          1.023380
# 75%          6.679821
# max       1959.167373
# Name: delta_days, dtype: float64
# Delta days per repository:
#                                                    count       mean  \
# repository
# https://github.com/containers/aardvark-dns         441.0   8.364324
# https://github.com/containers/buildah             5268.0  26.485463
# https://github.com/containers/common              1943.0   7.724231
# https://github.com/containers/conmon               443.0  23.534636
# https://github.com/containers/conmon-rs           2168.0   2.016250
# https://github.com/containers/container-selinux    263.0  39.373047
# https://github.com/containers/crun                1428.0   9.347357
# https://github.com/containers/image               2273.0  51.059643
# https://github.com/containers/netavark             917.0  14.721927
# https://github.com/containers/podman             20619.0  20.161337
# https://github.com/containers/podman-desktop      6308.0  31.913569
# https://github.com/containers/podman-py            347.0  38.224316
# https://github.com/containers/skopeo              2213.0  54.327206
# https://github.com/containers/storage             1856.0  17.756156
#
#                                                         std       min  \
# repository
# https://github.com/containers/aardvark-dns        32.436993  0.001806
# https://github.com/containers/buildah             89.137369  0.000046
# https://github.com/containers/common              42.288353  0.000081
# https://github.com/containers/conmon              71.713522  0.000706
# https://github.com/containers/conmon-rs           11.046264  0.000046
# https://github.com/containers/container-selinux  115.760779  0.000081
# https://github.com/containers/crun                40.828978  0.000116
# https://github.com/containers/image              181.129113  0.000093
# https://github.com/containers/netavark            68.489937  0.000637
# https://github.com/containers/podman              63.732317  0.000069
# https://github.com/containers/podman-desktop      88.651235  0.000069
# https://github.com/containers/podman-py          128.562582  0.000579
# https://github.com/containers/skopeo             177.999863  0.000046
# https://github.com/containers/storage             80.231636  0.000104
#
#                                                       25%       50%  \
# repository
# https://github.com/containers/aardvark-dns       0.169167  0.851539
# https://github.com/containers/buildah            0.397240  1.448032
# https://github.com/containers/common             0.094497  0.434537
# https://github.com/containers/conmon             0.215758  1.793264
# https://github.com/containers/conmon-rs          0.022208  0.058212
# https://github.com/containers/container-selinux  0.106238  0.942685
# https://github.com/containers/crun               0.137057  0.689902
# https://github.com/containers/image              0.183102  1.068356
# https://github.com/containers/netavark           0.188102  1.172593
# https://github.com/containers/podman             0.270139  1.315313
# https://github.com/containers/podman-desktop     0.067069  0.879219
# https://github.com/containers/podman-py          0.203530  2.187338
# https://github.com/containers/skopeo             0.196146  1.309155
# https://github.com/containers/storage            0.144083  0.768050
#
#                                                        75%          max
# repository
# https://github.com/containers/aardvark-dns        5.483588   508.802338
# https://github.com/containers/buildah             7.797205  1553.097639
# https://github.com/containers/common              1.686400   837.805347
# https://github.com/containers/conmon             11.410544   725.592361
# https://github.com/containers/conmon-rs           0.874881   287.859549
# https://github.com/containers/container-selinux   7.443669   988.010370
# https://github.com/containers/crun                2.441652   455.065440
# https://github.com/containers/image               7.973113  1861.893900
# https://github.com/containers/netavark            5.828391  1344.946759
# https://github.com/containers/podman              8.173600  1357.854850
# https://github.com/containers/podman-desktop      9.688157   743.537407
# https://github.com/containers/podman-py          11.566730   968.830914
# https://github.com/containers/skopeo             12.987106  1959.167373
# https://github.com/containers/storage             3.059557  1240.060012
# Delta days per author:
#                                           count        mean         std  \
# author_uuid
# 00091972243b8241ff39f992620661da13a4873f    4.0   32.837624   42.410067
# 000cf65b97aa6cc795a9d4518829bbb94b5748d4    3.0    7.454371   11.852324
# 0018cb5bc96ed14b8574b4d504577e6f317f3639    1.0    0.022419         NaN
# 0038e791611cd2c33f82dd7fbb050db4d0c855d7    6.0   27.015415   14.644568
# 003aed102bdc12d774028a90230144c74a4e80d7   15.0   15.697924   22.613641
# ...                                         ...         ...         ...
# ffd83128e468a79185d4614d95f8862e2edfa468    5.0  103.252595  146.621282
# ffe0f233beee6010492a0666be6815458c48b128    1.0    0.348333         NaN
# fff154c42f56ffc3645ff94037e8c8dc7d9bf733    1.0    0.007454         NaN
# fff20420a9e274e90971de359bebd7b0841d54fb    1.0    3.567859         NaN
# fff81c4b4ab08f1d748a26b99d8892e58639e356    0.0         NaN         NaN
#
#                                                 min        25%        50%  \
# author_uuid
# 00091972243b8241ff39f992620661da13a4873f   0.354861   3.755243  19.250457
# 000cf65b97aa6cc795a9d4518829bbb94b5748d4   0.007674   0.620584   1.233495
# 0018cb5bc96ed14b8574b4d504577e6f317f3639   0.022419   0.022419   0.022419
# 0038e791611cd2c33f82dd7fbb050db4d0c855d7  10.307778  15.540318  26.957824
# 003aed102bdc12d774028a90230144c74a4e80d7   0.026447   1.499525   3.868623
# ...                                             ...        ...        ...
# ffd83128e468a79185d4614d95f8862e2edfa468   0.253588   2.683843  19.183970
# ffe0f233beee6010492a0666be6815458c48b128   0.348333   0.348333   0.348333
# fff154c42f56ffc3645ff94037e8c8dc7d9bf733   0.007454   0.007454   0.007454
# fff20420a9e274e90971de359bebd7b0841d54fb   3.567859   3.567859   3.567859
# fff81c4b4ab08f1d748a26b99d8892e58639e356        NaN        NaN        NaN
#
#                                                  75%         max
# author_uuid
# 00091972243b8241ff39f992620661da13a4873f   48.332839   92.494722
# 000cf65b97aa6cc795a9d4518829bbb94b5748d4   11.177720   21.121944
# 0018cb5bc96ed14b8574b4d504577e6f317f3639    0.022419    0.022419
# 0038e791611cd2c33f82dd7fbb050db4d0c855d7   36.157622   46.910359
# 003aed102bdc12d774028a90230144c74a4e80d7   19.400272   67.349410
# ...                                              ...         ...
# ffd83128e468a79185d4614d95f8862e2edfa468  155.328067  338.813507
# ffe0f233beee6010492a0666be6815458c48b128    0.348333    0.348333
# fff154c42f56ffc3645ff94037e8c8dc7d9bf733    0.007454    0.007454
# fff20420a9e274e90971de359bebd7b0841d54fb    3.567859    3.567859
# fff81c4b4ab08f1d748a26b99d8892e58639e356         NaN         NaN
#
# [5931 rows x 8 columns]
